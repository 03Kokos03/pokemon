# %%
import pandas as pd
poke = pd.read_csv("pokemon_data.csv")
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
poke.shape
# Out:
# (800, 13)

# %%
poke.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
poke['Name'][:11]
# Out:
# 0                     Bulbasaur
# 1                       Ivysaur
# 2                      Venusaur
# 3         VenusaurMega Venusaur
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# Name: Name, dtype: object

# %%
poke.iloc[4]
# Out:
# #                      4
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# Total                309
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object

# %%
poke.iloc[7,3]
# Out:
# 'Dragon'

# %%
for index , row in poke.iterrows():
    print(index , row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran♀
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran♂
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# ...

# %%
poke.loc[poke['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
poke.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
poke.sort_values("HP")
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 487  439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke.sort_values("Speed" , ascending = False)
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 431  386          DeoxysSpeed Forme  Psychic     NaN    600   50      95
# 315  291                    Ninjask      Bug  Flying    456   61      90
# 428  386         DeoxysNormal Forme  Psychic     NaN    600   50     150
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615   80     135
# 71    65      AlakazamMega Alakazam  Psychic     NaN    590   55      50
# ..   ...                        ...      ...     ...    ...  ...     ...
# 658  597                  Ferroseed    Grass   Steel    305   44      50
# 486  438                     Bonsly     Rock     NaN    290   50      80
# 359  328                   Trapinch   Ground     NaN    290   45     100
# 230  213                    Shuckle      Bug    Rock    505   20      10
# 495  446                   Munchlax   Normal     NaN    390  135      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke["Total"] = poke["HP"] + poke["Attack"] + poke["Defense"] + poke["Sp. Atk"] + poke["Sp. Def"] + poke["Speed"] 
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
poke.sort_values("Total" , ascending = False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                    ...      ...       ...    ...  ...     ...
# 13    10               Caterpie      Bug       NaN    195   45      30
# 288  265                Wurmple      Bug       NaN    195   45      45
# 446  401              Kricketot      Bug       NaN    194   37      25
# 322  298                Azurill   Normal     Fairy    190   50      20
# 206  191                Sunkern    Grass       NaN    180   30      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke = poke.drop(columns=['Type 1', 'Type 2', 'Legendary'])
poke
# Out:
#        #                   Name  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1              Bulbasaur    318  45      49       49       65       65
# 1      2                Ivysaur    405  60      62       63       80       80
# 2      3               Venusaur    525  80      82       83      100      100
# 3      3  VenusaurMega Venusaur    625  80     100      123      122      120
# 4      4             Charmander    309  39      52       43       60       50
# ..   ...                    ...    ...  ..     ...      ...      ...      ...
# 795  719                Diancie    600  50     100      150      100      150
# 796  719    DiancieMega Diancie    700  50     160      110      160      110
# 797  720    HoopaHoopa Confined    600  80     110       60      150      130
# 798  720     HoopaHoopa Unbound    680  80     160       60      170      130
# 799  721              Volcanion    600  80     110      120      130       90
#
#      Speed  Generation
# ...

# %%
import matplotlib.pyplot as plt

# %%
poke_corr = poke.corr(method ='pearson')
poke_corr
# Out:
# C:\Users\Michał\AppData\Local\Temp\ipykernel_16596\2317415419.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   poke_corr = poke.corr(method ='pearson')
#                    #     Total        HP    Attack   Defense   Sp. Atk  \
# #           1.000000  0.119813  0.097614  0.102298  0.094786  0.088759
# Total       0.119813  1.000000  0.618748  0.736211  0.612787  0.747250
# HP          0.097614  0.618748  1.000000  0.422386  0.239622  0.362380
# Attack      0.102298  0.736211  0.422386  1.000000  0.438687  0.396362
# Defense     0.094786  0.612787  0.239622  0.438687  1.000000  0.223549
# Sp. Atk     0.088759  0.747250  0.362380  0.396362  0.223549  1.000000
# Sp. Def     0.085817  0.717609  0.378718  0.263990  0.510747  0.506121
# Speed       0.010733  0.575943  0.175952  0.381240  0.015227  0.473018
# ...

# %%
poke_mean1 = poke.loc[poke['Generation'] == 1, 'Total'].mean()
poke_mean1
# Out:
# 426.81325301204816

# %%
poke_mean_HP1 = poke.loc[poke['Generation'] == 1, 'HP'].mean()
poke_mean_HP1
# Out:
# 65.81927710843374

# %%
poke_mean2 = poke.loc[poke['Generation'] == 2, 'Total'].mean()
poke_mean2
# Out:
# 418.2830188679245

# %%
poke_mean_HP2 = poke.loc[poke['Generation'] == 2, 'HP'].mean()
poke_mean_HP2
# Out:
# 71.20754716981132

# %%
poke_mean3 = poke.loc[poke['Generation'] == 3, 'Total'].mean()
poke_mean3
# Out:
# 436.225

# %%
poke_mean_HP3 = poke.loc[poke['Generation'] == 3, 'HP'].mean()
poke_mean_HP3
# Out:
# 66.54375

# %%
poke_mean4 = poke.loc[poke['Generation'] == 4, 'Total'].mean()
poke_mean4
# Out:
# 459.0165289256198

# %%
poke_mean_HP4 = poke.loc[poke['Generation'] == 4, 'HP'].mean()
poke_mean_HP4
# Out:
# 73.08264462809917

# %%
poke_mean5 = poke.loc[poke['Generation'] == 5, 'Total'].mean()
poke_mean5
# Out:
# 434.9878787878788

# %%
poke_mean_HP5 = poke.loc[poke['Generation'] == 5, 'HP'].mean()
poke_mean_HP5
# Out:
# 71.78787878787878

# %%
poke_mean6 = poke.loc[poke['Generation'] == 6, 'Total'].mean()
poke_mean6
# Out:
# 436.3780487804878

# %%
poke_mean_HP6 = poke.loc[poke['Generation'] == 6, 'HP'].mean()
poke_mean_HP6
# Out:
# 68.26829268292683

# %%
data = [[poke_mean1, poke_mean_HP1, 1], 
        [poke_mean2, poke_mean_HP2, 2],
        [poke_mean3, poke_mean_HP3, 3] ,
        [poke_mean6, poke_mean_HP4, 4], 
        [poke_mean5, poke_mean_HP5, 5], 
        [poke_mean6, poke_mean_HP6, 6]]
poke_mean = pd.DataFramedf = pd.DataFrame(data, columns=['mean_total', 'mean_HP', 'generation'])

poke_mean
# Out:
#    mean_total    mean_HP  generation
# 0  426.813253  65.819277           1
# 1  418.283019  71.207547           2
# 2  436.225000  66.543750           3
# 3  436.378049  73.082645           4
# 4  434.987879  71.787879           5
# 5  436.378049  68.268293           6

# %%
poke_mean.plot(x ='generation' , y = 'mean_total' , label='mean_total' , linestyle="--" ,marker='.' , markersize=8)
plt.xticks([1,2,3,4,5,6])
plt.yticks([400, 410, 420, 430, 440 ,450])
plt.savefig('graph_poke_2.png')

poke_mean.plot(x ='generation' , y = 'mean_HP' , label='mean_HP' , linestyle="--" ,marker='.' , markersize=8 , color='red')
plt.xticks([1,2,3,4,5,6])
plt.yticks([55, 60, 65, 70, 75 ,80])

plt.legend()

plt.savefig('graph_poke_1.png')
plt.show()

# %%
poke_mean.mean_HP.plot(label='mean_HP' , linestyle="--" ,marker='.' )
poke_mean.mean_total.plot(label='mean_total' , linestyle="--" ,marker='.' )
plt.xticks([1,2,3,4,5,6])
plt.yticks([0, 90, 180, 270, 360 ,450])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
